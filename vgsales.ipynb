# %%
import pandas as pd

# %%
game = pd.read_csv("vgsales.csv")

# %%
game
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game["Publisher"]
# Out:
# 0          Nintendo
# 1          Nintendo
# 2          Nintendo
# 3          Nintendo
# 4          Nintendo
#             ...
# 16593         Kemco
# 16594    Infogrames
# 16595    Activision
# 16596      7G//AMES
# 16597       Wanadoo
# Name: Publisher, Length: 16598, dtype: object

# %%
pub = game[game["Publisher"] == "Nintendo"]  
pub
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16456  16459                           Art Academy: Home Studio     WiiU
# 16473  16476                                    Captain Rainbow      Wii
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
pub = game[game["Name"] == "Star Fox"]

# %%
pub
# Out:
#      Rank      Name Platform    Year    Genre Publisher  NA_Sales  EU_Sales  \
# 472   473  Star Fox     SNES  1993.0  Shooter  Nintendo      1.61      0.51
#
#      JP_Sales  Other_Sales  Global_Sales
# 472       0.8         0.07          2.99

# %%
portal = game[game["Name"] == "Portal 2"]
portal
# Out:
#       Rank      Name Platform    Year    Genre       Publisher  NA_Sales  \
# 789    791  Portal 2     X360  2011.0  Shooter  Valve Software      1.41
# 1016  1018  Portal 2      PS3  2011.0  Shooter           Valve      0.83
# 2699  2701  Portal 2       PC  2011.0  Shooter  Valve Software      0.33
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 789       0.51      0.01         0.17          2.10
# 1016      0.63      0.02         0.25          1.74
# 2699      0.32      0.00         0.11          0.76

# %%
sales = game[game["Global_Sales"] > 30]
sales
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7     New Super Mario Bros.       DS  2006.0      Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# ...

# %%
sales["Global_Sales"].sum()
# Out:
# 283.44

# %%
Global = game["Global_Sales"].mean()
print(Global)
# Out:
# 0.53744065550074

# %%
add = game["EU_Sales"] + game["NA_Sales"]
add
# Out:
# 0        70.51
# 1        32.66
# 2        28.73
# 3        26.76
# 4        20.16
#          ...
# 16593     0.01
# 16594     0.01
# 16595     0.00
# 16596     0.01
# 16597     0.01
# Length: 16598, dtype: float64

# %%
add2 = game["JP_Sales"] + game["Other_Sales"]
add2
# Out:
# 0        12.23
# 1         7.58
# 2         7.10
# 3         6.24
# 4        11.22
#          ...
# 16593     0.00
# 16594     0.00
# 16595     0.00
# 16596     0.00
# 16597     0.00
# Length: 16598, dtype: float64

# %%
moyenne = add.mean()
moyenne
# Out:
# 0.4113194360766579

# %%
moyenne1= add2.mean()
moyenne1
# Out:
# 0.12584468008193642

# %% [markdown]
# game

# %%
game
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
import numpy

# %%
pub1 = game.pivot_table(index="Publisher", values="Global_Sales", aggfunc=numpy.mean)
pub1
# Out:
#                               Global_Sales
# Publisher
# 10TACLE Studios                   0.036667
# 1C Company                        0.033333
# 20th Century Fox Video Games      0.388000
# 2D Boy                            0.040000
# 3DO                               0.281111
# ...                                    ...
# id Software                       0.030000
# imageepoch Inc.                   0.020000
# inXile Entertainment              0.100000
# mixi, Inc                         0.860000
# responDESIGN                      0.065000
#
# [578 rows x 1 columns]

# %%
pub1.sort_values("Global_Sales", inplace = False, ascending = False)
# Out:
#                            Global_Sales
# Publisher
# Palcom                         4.170000
# Red Orb                        2.620000
# Nintendo                       2.541337
# Arena Entertainment            2.360000
# UEP Systems                    2.250000
# ...                                 ...
# Paradox Development            0.010000
# Commseed                       0.010000
# Nitroplus                      0.010000
# Boost On                       0.010000
# EON Digital Entertainment      0.010000
#
# [578 rows x 1 columns]

# %%
year = game[game["Year"] == 1989]
year
# Out:
#         Rank                              Name Platform    Year         Genre  \
# 5          6                            Tetris       GB  1989.0        Puzzle
# 21        22                  Super Mario Land       GB  1989.0      Platform
# 170      171                         Dr. Mario       GB  1989.0        Puzzle
# 276      277      Teenage Mutant Ninja Turtles      NES  1989.0        Action
# 775      777                              Golf       GB  1989.0        Sports
# 852      854                            Tennis       GB  1989.0        Sports
# 880      882                          Alleyway       GB  1989.0        Puzzle
# 1089    1091                Disney's DuckTales      NES  1989.0      Platform
# 1142    1144                          Baseball       GB  1989.0        Sports
# 1542    1544                           Yakuman       GB  1989.0          Misc
# 1678    1680                      SolarStriker       GB  1989.0       Shooter
# ...

# %%
matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
toto = game.sort_values("Year", inplace=False, ascending=True)
toto
# Out:
#         Rank                         Name Platform    Year         Genre  \
# 6896    6898                     Checkers     2600  1980.0          Misc
# 2669    2671                       Boxing     2600  1980.0      Fighting
# 5366    5368                      Freeway     2600  1980.0        Action
# 1969    1971                     Defender     2600  1980.0          Misc
# 1766    1768                      Kaboom!     2600  1980.0          Misc
# ...      ...                          ...      ...     ...           ...
# 16307  16310                Freaky Flyers       GC     NaN        Racing
# 16327  16330                    Inversion       PC     NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3     NaN     Adventure
# 16427  16430                 Virtua Quest       GC     NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS     NaN        Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
toto1=toto[0:15000]
toto1
# Out:
#         Rank                                               Name Platform  \
# 6896    6898                                           Checkers     2600
# 2669    2671                                             Boxing     2600
# 5366    5368                                            Freeway     2600
# 1969    1971                                           Defender     2600
# 1766    1768                                            Kaboom!     2600
# ...      ...                                                ...      ...
# 410      411                                            Destiny     XOne
# 10391  10393                         BlazBlue: Chrono Phantasma      PSV
# 561      562                             Yokai Watch 2 Shinuchi      3DS
# 13598  13600  Doraemon: Shin Nobita no Daimakyou Peko to 5-n...      3DS
# 10394  10396  Earth Defense Force 2: Invaders from Planet Space      PSV
#
#          Year         Genre         Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
plt.plot(toto1["Year"], toto1["Global_Sales"])
# axe x = first_year colonne "Year"
# axe y = first_year colonne "Global_Sales"


plt.show()
